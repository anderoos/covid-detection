# %%
from IPython import display
import os
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random as python_random
import tensorflow as tf
import seaborn as sns
import math
from sklearn.metrics import classification_report, confusion_matrix

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#c54f42;
#            font-size:300%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="font-size:30px;text-align:center">Covid19 chest image VGG16 prediction🎯</p>
# </div>

# %% [markdown]
# <p style="text-align:center;"><img src="http://contemporarysecuritypolicy.org/files/2020/03/200309-D-HN545-003.jpeg" width="500" height="350">

# %% [markdown]
# Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus.
#
# Most people who fall sick with COVID-19 will experience mild to moderate symptoms and recover without special treatment.
#
# However, some will become seriously ill and require medical attention.
#
# In general, respiratory specimens such as deep throat saliva, combined throat and nasal swab and nasopharyngeal specimens
#
# are the specimen types of choice for diagnosing COVID-19 infection.
#
# <h3>Objective of this kernel...</h3>
#
# The CNN image classification could also be the one of approaches to diagnose the covid19.
#
# By obtaining the xray images, it can be one of the effective alternatives to diagnose the patient who is potentially infected with covid.

# %%
# ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from PIL import ImageFilter

height, width = 224, 224
batch_size=64

def generate_data(DIR):
    datagen = ImageDataGenerator(rescale=1./255.)
    
    generator = datagen.flow_from_directory(
        DIR,
        batch_size=batch_size,
        shuffle=True,
        seed=42,
        class_mode='binary',
        target_size=(height, width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator

TRAINING_DIR = "covid19-resources/train"
TESTING_DIR = "covid19-resources/test"

train_generator = generate_data(TRAINING_DIR)
test_generator = generate_data(TESTING_DIR)

total_image = np.concatenate([train_generator.labels,test_generator.labels])

print('\n\n',{'Normal_cases':len(np.where(total_image==0)[0]),
      'Viral_Pneumonia_cases':len(np.where(total_image==1)[0]),
             'Covid_cases':len(np.where(total_image==2)[0])})
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
#
#
#  {'Normal_cases': 90, 'Viral_Pneumonia_cases': 90, 'Covid_cases': 137}

# %% [markdown]
# <h3>Images demonstration<h3>

# %%
def image_plot(generator,image_numbers):
    img_feature = generator[0][0][:image_numbers]
    img_label = generator[0][1][:image_numbers]

    plt.figure(figsize=(20, 15))
    for i in range(image_numbers):
        ax = plt.subplot(math.ceil(image_numbers/4),4, i + 1)
        plt.imshow(img_feature[i])
        plt.title("Normal" if img_label[i] == 0 else "Viral Pneumonia" if img_label[i] == 1 else "Covid")
        plt.axis("off")

image_plot(train_generator,15)

# %% [markdown]
# <h3>VGG16 implementation</h3>
#
# The reason that I added 2 more dense layers is to identify more clearly from the grayscale image.
#
# The dropout layers are regularization for preventing overfitting.

# %%
from tensorflow.keras.layers.experimental import preprocessing

tf.keras.backend.clear_session()
input_shape = (height, width, 3)
base_model = tf.keras.applications.vgg16.VGG16(
    weights='imagenet', 
    include_top=False,
    input_shape=input_shape
)
base_model.trainable = False

model_vgg16 = tf.keras.Sequential()
model_vgg16.add(base_model)
model_vgg16.add(tf.keras.layers.GlobalAveragePooling2D())

model_vgg16.add(tf.keras.layers.Flatten())
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))

model_vgg16.add(tf.keras.layers.Dense(3, activation='softmax'))

model_vgg16.compile(loss='SparseCategoricalCrossentropy', 
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['acc'])
model_vgg16.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 14912579 (56.89 MB)
# Trainable params: 197891 (773.01 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=5)

callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        train_generator,
        validation_data = test_generator,
        #steps_per_epoch=10,
        epochs=50, 
        shuffle=False, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2551 - acc: 0.3785
# Epoch 1: acc improved from -inf to 0.37849, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 23s 6s/step - loss: 1.2551 - acc: 0.3785 - val_loss: 1.0599 - val_acc: 0.3939
# Epoch 2/50
# /Users/andrewcheng/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - ETA: 0s - loss: 1.1125 - acc: 0.4502
# Epoch 2: acc improved from 0.37849 to 0.45020, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 1.1125 - acc: 0.4502 - val_loss: 0.9516 - val_acc: 0.5606
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0102 - acc: 0.4940
# Epoch 3: acc improved from 0.45020 to 0.49402, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 1.0102 - acc: 0.4940 - val_loss: 0.8869 - val_acc: 0.7273
# Epoch 4/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9554 - acc: 0.5339
# Epoch 4: acc improved from 0.49402 to 0.53386, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.9554 - acc: 0.5339 - val_loss: 0.8343 - val_acc: 0.6970
# Epoch 5/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8396 - acc: 0.6255
# Epoch 5: acc improved from 0.53386 to 0.62550, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 0.8396 - acc: 0.6255 - val_loss: 0.7437 - val_acc: 0.8182
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7677 - acc: 0.6534
# Epoch 6: acc improved from 0.62550 to 0.65339, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 6s/step - loss: 0.7677 - acc: 0.6534 - val_loss: 0.6563 - val_acc: 0.8030
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7297 - acc: 0.7052
# Epoch 7: acc improved from 0.65339 to 0.70518, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 0.7297 - acc: 0.7052 - val_loss: 0.5779 - val_acc: 0.8788
# Epoch 8/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6331 - acc: 0.7331
# Epoch 8: acc improved from 0.70518 to 0.73307, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 6s/step - loss: 0.6331 - acc: 0.7331 - val_loss: 0.5170 - val_acc: 0.8485
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6055 - acc: 0.7570
# Epoch 9: acc improved from 0.73307 to 0.75697, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.6055 - acc: 0.7570 - val_loss: 0.4733 - val_acc: 0.8333
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 0.5642 - acc: 0.7849
# Epoch 10: acc improved from 0.75697 to 0.78486, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 6s/step - loss: 0.5642 - acc: 0.7849 - val_loss: 0.4423 - val_acc: 0.9091
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4966 - acc: 0.8127
# Epoch 11: acc improved from 0.78486 to 0.81275, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 0.4966 - acc: 0.8127 - val_loss: 0.4148 - val_acc: 0.8182
# Epoch 12/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4725 - acc: 0.8367
# Epoch 12: acc improved from 0.81275 to 0.83665, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.4725 - acc: 0.8367 - val_loss: 0.3868 - val_acc: 0.8485
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4410 - acc: 0.8367
# Epoch 13: acc did not improve from 0.83665
# 4/4 [==============================] - 21s 5s/step - loss: 0.4410 - acc: 0.8367 - val_loss: 0.3664 - val_acc: 0.8485
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4536 - acc: 0.8526
# Epoch 14: acc improved from 0.83665 to 0.85259, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 0.4536 - acc: 0.8526 - val_loss: 0.3422 - val_acc: 0.8788
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 0.4013 - acc: 0.8446
# Epoch 15: acc did not improve from 0.85259
# 4/4 [==============================] - 22s 5s/step - loss: 0.4013 - acc: 0.8446 - val_loss: 0.3212 - val_acc: 0.9091
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3620 - acc: 0.8566
# Epoch 16: acc improved from 0.85259 to 0.85657, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.3620 - acc: 0.8566 - val_loss: 0.3172 - val_acc: 0.8485
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3523 - acc: 0.8765
# Epoch 17: acc improved from 0.85657 to 0.87649, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 6s/step - loss: 0.3523 - acc: 0.8765 - val_loss: 0.2934 - val_acc: 0.9091
# Epoch 18/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3355 - acc: 0.8765
# Epoch 18: acc did not improve from 0.87649
# 4/4 [==============================] - 22s 5s/step - loss: 0.3355 - acc: 0.8765 - val_loss: 0.2804 - val_acc: 0.8939
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 0.3023 - acc: 0.9084
# Epoch 19: acc improved from 0.87649 to 0.90837, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 0.3023 - acc: 0.9084 - val_loss: 0.2867 - val_acc: 0.8485
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2919 - acc: 0.8964
# Epoch 20: acc did not improve from 0.90837
# 4/4 [==============================] - 23s 6s/step - loss: 0.2919 - acc: 0.8964 - val_loss: 0.2913 - val_acc: 0.8333
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2647 - acc: 0.9084
# Epoch 21: acc did not improve from 0.90837
# 4/4 [==============================] - 22s 5s/step - loss: 0.2647 - acc: 0.9084 - val_loss: 0.2584 - val_acc: 0.8939
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2749 - acc: 0.9084
# Epoch 22: acc did not improve from 0.90837
# 4/4 [==============================] - 22s 5s/step - loss: 0.2749 - acc: 0.9084 - val_loss: 0.2393 - val_acc: 0.9394
# Epoch 23/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2557 - acc: 0.9044
# Epoch 23: acc did not improve from 0.90837
# 4/4 [==============================] - 22s 5s/step - loss: 0.2557 - acc: 0.9044 - val_loss: 0.2342 - val_acc: 0.8939
# Epoch 24/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2175 - acc: 0.9363
# Epoch 24: acc improved from 0.90837 to 0.93625, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 0.2175 - acc: 0.9363 - val_loss: 0.2421 - val_acc: 0.8788
# Epoch 25/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1972 - acc: 0.9442
# Epoch 25: acc improved from 0.93625 to 0.94422, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.1972 - acc: 0.9442 - val_loss: 0.2289 - val_acc: 0.8939
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2138 - acc: 0.9203
# Epoch 26: acc did not improve from 0.94422
# 4/4 [==============================] - 21s 5s/step - loss: 0.2138 - acc: 0.9203 - val_loss: 0.2087 - val_acc: 0.9394
# Epoch 27/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1955 - acc: 0.9323
# Epoch 27: acc did not improve from 0.94422
# 4/4 [==============================] - 21s 5s/step - loss: 0.1955 - acc: 0.9323 - val_loss: 0.2617 - val_acc: 0.8485
# Epoch 28/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1729 - acc: 0.9323
# Epoch 28: acc did not improve from 0.94422
# 4/4 [==============================] - 22s 5s/step - loss: 0.1729 - acc: 0.9323 - val_loss: 0.2026 - val_acc: 0.9091
# Epoch 29/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1796 - acc: 0.9482
# Epoch 29: acc improved from 0.94422 to 0.94821, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.1796 - acc: 0.9482 - val_loss: 0.1926 - val_acc: 0.9394
# Epoch 30/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1894 - acc: 0.9402
# Epoch 30: acc did not improve from 0.94821
# 4/4 [==============================] - 21s 5s/step - loss: 0.1894 - acc: 0.9402 - val_loss: 0.2134 - val_acc: 0.8939
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2042 - acc: 0.9203
# Epoch 31: acc did not improve from 0.94821
# 4/4 [==============================] - 21s 5s/step - loss: 0.2042 - acc: 0.9203 - val_loss: 0.1940 - val_acc: 0.8939
# Epoch 32/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1727 - acc: 0.9323
# Epoch 32: acc did not improve from 0.94821
# 4/4 [==============================] - 21s 5s/step - loss: 0.1727 - acc: 0.9323 - val_loss: 0.1821 - val_acc: 0.9242
# Epoch 33/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1481 - acc: 0.9562
# Epoch 33: acc improved from 0.94821 to 0.95618, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.1481 - acc: 0.9562 - val_loss: 0.1907 - val_acc: 0.9091
# Epoch 34/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1648 - acc: 0.9402
# Epoch 34: acc did not improve from 0.95618
# 4/4 [==============================] - 22s 5s/step - loss: 0.1648 - acc: 0.9402 - val_loss: 0.2025 - val_acc: 0.8939
# Epoch 35/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1358 - acc: 0.9442
# Epoch 35: acc did not improve from 0.95618
# 4/4 [==============================] - 22s 6s/step - loss: 0.1358 - acc: 0.9442 - val_loss: 0.1724 - val_acc: 0.9394
# Epoch 36/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1434 - acc: 0.9363
# Epoch 36: acc did not improve from 0.95618
# 4/4 [==============================] - 22s 5s/step - loss: 0.1434 - acc: 0.9363 - val_loss: 0.1698 - val_acc: 0.9394
# Epoch 37/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1514 - acc: 0.9402
# Epoch 37: acc did not improve from 0.95618
# 4/4 [==============================] - 22s 5s/step - loss: 0.1514 - acc: 0.9402 - val_loss: 0.1696 - val_acc: 0.9394
# Epoch 38/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1043 - acc: 0.9641
# Epoch 38: acc improved from 0.95618 to 0.96414, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 22s 5s/step - loss: 0.1043 - acc: 0.9641 - val_loss: 0.1775 - val_acc: 0.9091
# Epoch 39/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1260 - acc: 0.9681
# Epoch 39: acc improved from 0.96414 to 0.96813, saving model to model/vgg16_best.h5
# 4/4 [==============================] - 24s 6s/step - loss: 0.1260 - acc: 0.9681 - val_loss: 0.1731 - val_acc: 0.9242
# Epoch 40/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1635 - acc: 0.9203
# Epoch 40: acc did not improve from 0.96813
# 4/4 [==============================] - 26s 7s/step - loss: 0.1635 - acc: 0.9203 - val_loss: 0.1654 - val_acc: 0.9545
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1217 - acc: 0.9482
# Epoch 41: acc did not improve from 0.96813
# 4/4 [==============================] - 26s 6s/step - loss: 0.1217 - acc: 0.9482 - val_loss: 0.1635 - val_acc: 0.9697
# Epoch 42/50
# 4/4 [==============================] - ETA: 0s - loss: 0.1393 - acc: 0.9363
# Epoch 42: acc did not improve from 0.96813
# 4/4 [==============================] - 25s 6s/step - loss: 0.1393 - acc: 0.9363 - val_loss: 0.2027 - val_acc: 0.9091
# Epoch 43/50
# 1/4 [======>.......................] - ETA: 19s - loss: 0.1045 - acc: 0.9688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       2 early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=5)
#       4 callbacks_list = [checkpoint,early]
# ----> 6 history = model_vgg16.fit(
#       7         train_generator,
#       8         validation_data = test_generator,
#       9         #steps_per_epoch=10,
#      10         epochs=50,
#      11         shuffle=False,
#      12         verbose=True,
#      13         callbacks=callbacks_list)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.legend();
    plt.figure();

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.legend();

plot_learning_curve(history)

# %%
train_result = model_vgg16.evaluate(train_generator)
test_result = model_vgg16.evaluate(test_generator)

no_augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
no_augmented_df

# %%
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_generator.classes)/batch_size)):
    xtest.append(test_generator[i][0]) 
    ytest= np.concatenate((ytest,test_generator[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model_vgg16.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))

# %% [markdown]
# <h3>Show the wrong classified image</h3>

# %%
#Extract wrong classification index
wrong_pred = np.where(ypred!=ytest)[0]

plt.figure(figsize=(20, 15))
for i,n in enumerate(wrong_pred):
    ax = plt.subplot(math.ceil(len(wrong_pred)/4),4, i + 1)
    plt.imshow(xtest[n])
    plt.title("Normal" if ypred[n] == 0 else "Viral Pneumonia" if ypred[n] == 1 else "Covid",color='r')
    plt.axis("off")

# %% [markdown]
# Well, actually they looks similar 🙃

# %% [markdown]
# <h3>Adding image augmentation</h3>

# %%
def generate_data_augmented(DIR):
    datagen = ImageDataGenerator(
        rescale=1./255.,
        zoom_range=0.1,
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True
    )
    generator = datagen.flow_from_directory(
        TRAINING_DIR,
        batch_size=batch_size,
        seed=42,
        class_mode='binary',
        target_size=(height, width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator

aug_train_generator = generate_data_augmented(TRAINING_DIR)

image_plot(aug_train_generator,15)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=10)

callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        aug_train_generator,
        validation_data = test_generator,
        #steps_per_epoch=10,
        epochs=60, 
        shuffle=False, 
        verbose=True,
        callbacks=callbacks_list)

# %%
train_result = model_vgg16.evaluate(train_generator)
test_result = model_vgg16.evaluate(test_generator)

augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
augmented_df

# %% [markdown]
# <h3>Final model evaluation</h3>

# %% [markdown]
# For training dataset

# %%
ytrain = np.array([])
xtrain = []

for i in range(math.ceil(len(train_generator.classes)/batch_size)):
    xtrain.append(train_generator[i][0]) 
    ytrain= np.concatenate((ytrain,train_generator[i][-1])) 
    
xtrain = np.concatenate((xtrain),axis=0)

ypred_prob =model_vgg16.predict(xtrain)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytrain,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytrain,ypred))

# %% [markdown]
# For testing dataset

# %%
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_generator.classes)/batch_size)):
    xtest.append(test_generator[i][0]) 
    ytest= np.concatenate((ytest,test_generator[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model_vgg16.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))

# %% [markdown]
# <h2>
#
# Great!!
#
# The model can classify all the covid image correctly and overall the accuracy can achieve 98%.
#
# Thanks for viewing my works
#
# Your comment matters to me and please feel free to leave it
#
# Please upvote if you love it 😀</h2>
